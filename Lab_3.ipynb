# %% [markdown]
# <a href="https://colab.research.google.com/github/beaconfident/FMML/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-14 09:26:55--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   105MB/s    in 0.7s
#
# 2025-03-14 09:26:58 (105 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 21975   1211.3038v4  We prove that the density function of the grad...  stat
# 21090  1707.07763v2  In recent work, we proved that the domain recu...    cs
# 14968  1604.00400v1  Evaluation of text summarization approaches ha...    cs
# 752    1710.09300v1  Data and knowledge representation are fundamen...    cs
# 3413   1702.06890v2  Person recognition aims at recognizing the sam...    cs
# ...             ...                                                ...   ...
# 22561  1611.10073v2  The construction of synthetic complex-valued s...  stat
# 11053   1312.5179v1  Hypergraphs allow one to encode higher-order r...  stat
# 2391    1303.0691v3  This paper deals with chain graphs under the A...  stat
# 2602   1609.07521v1  Mixture models and topic models generate each ...  stat
# 22552  1611.05940v2  We propose a method for finding alternate feat...  stat
#
#                                                    title  year  \
# 21975  Gradient density estimation in arbitrary finit...  2012
# 21090  Domain Recursion for Lifted Inference with Exi...  2017
# 14968  Revisiting Summarization Evaluation for Scient...  2016
# 752    Feature learning in feature-sample networks us...  2017
# 3413   Learning Deep Features via Congenerous Cosine ...  2017
# ...                                                  ...   ...
# 22561  Complex-valued Gaussian Process Regression for...  2016
# 11053  The Total Variation on Hypergraphs - Learning ...  2013
# 2391   Learning AMP Chain Graphs and some Marginal Mo...  2013
# 2602   Fast Learning of Clusters and Topics via Spars...  2016
# 22552                Finding Alternate Features in Lasso  2016
#
#                                                 keywords
# 21975  [sufficiently, rightarrow, transformation, uni...
# 21090  [recursion, inference, inference, relational, ...
# 14968  [evaluation, summarization, approaches, simila...
# 752    [knowledge, representation, fundamental, repre...
# 3413   [recognition, recognizing, complicated, appear...
# ...                                                  ...
# 22561  [construction, synthetic, observations, import...
# 11053  [hypergraphs, relationships, approximations, h...
# 2391   [andersson, interpretation, particular, constr...
# 2602   [observation, variational, posteriors, observa...
# 22552  [alternate, resulting, interpreted, alternate,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 21975    [sufficiently, rightarrow, transformation, uni...
# 21090    [recursion, inference, inference, relational, ...
# 14968    [evaluation, summarization, approaches, simila...
# 752      [knowledge, representation, fundamental, repre...
# 3413     [recognition, recognizing, complicated, appear...
#                                ...
# 14933    [assigning, challenging, sentiment, literature...
# 10751    [conditional, filtering, algorithm, efficient,...
# 18676    [knowledge, discovery, interpretation, evaluat...
# 2647     [randomized, functions, exploration, reinforce...
# 6241     [challenge, organized, conjunction, competitio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8687 words.
# Out of those 4556 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="878940f0-0230-4c50-8fca-632528053ae9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("878940f0-0230-4c50-8fca-632528053ae9")) {                    Plotly.newPlot(                        "878940f0-0230-4c50-8fca-632528053ae9",                        [{"x":["techniques","stationary","dimensions","transformation","integration","approximation","estimation","relationship","sufficiently","characteristic","arbitrary","rightarrow","increasingly","highlight","distributed","uniformly","approximated","normalized","parameter","introducing","exponential","quantifiers","algorithms","recursion","complexity","processing","potentially","probability","interesting","theoretical","inconvenient","understanding","currently","previously","inference","existential","identified","skolemization","relational","therefore","evaluating","terminology","furthermore","alternative","revisiting","summarization","summaries","effectiveness","effective","sentences","approaches","evaluation","generated","correlations","scientific","corresponding","different","extensive","consistently","variations","paraphrasing","similarities","relevance","knowledge","unsupervised","metaheuristics","discussed","structures","fundamental","exploited","optimization","combination","objective","preexisting","lexicographic","mechanism","performance","nonlinear","information","disadvantages","transforms","effectively","algorithm","representation","dimensional","advantages","evolutionary","appearance","representative","determined","recognizing","implemented","distinction","cooperative","alleviating","classification","experimental","measuring","minimizing","intuition","recognition","similarity","complicated","reference","transitions","filtering","correspond","reconstructing","quantifies","intrinsic","predictive","underlying","estimates","reconstruction","partition","frameworks","introduces","structure","according","perspective","application","detection","demonstrated","important","supporting","cognitive","computational","artificial","principles","attraction","implements","prototypical","autonomous","selective","comprises","recurrent","equilibrium","attractors","implement","separation","operating","presentation","plasticity","neuromorphic","experiments","connectivity","attractor","relaxation","parameters","following","associative","primitives","retrieval","memorized","connection","exploiting","appropriate","homogeneous","evolution","comparing","phenomenological","simulated","navigation","topologies","implementations","adaptation","heterogeneous","demonstrate","memristors","memristor","connections","properties","comprised","memristive","scenarios","evaluated","applications","specifically","multipliers","structured","meaningful","alternating","regularized","minimized","quadratic","biological","compressive","resulting","regularize","abundance","simultaneously","conventional","illustrated","correlation","consisting","substantially","hyperspectral","introduced","innovative","minimization"],"y":[392,25,51,59,43,104,212,62,29,21,77,2,45,32,110,13,14,31,139,57,41,6,603,10,246,298,47,161,79,152,3,151,53,82,229,4,46,2,34,138,54,9,143,107,7,24,18,215,243,72,474,249,156,20,44,128,745,166,40,77,2,36,40,342,132,6,44,131,78,35,343,152,180,1,4,121,855,54,665,8,20,112,819,407,160,89,83,59,39,40,32,95,4,15,4,507,376,32,53,13,377,139,38,56,11,65,26,14,6,40,59,119,64,113,35,27,85,333,107,80,226,309,90,344,24,46,280,142,42,4,21,11,53,15,16,148,14,2,70,32,22,14,9,12,562,19,2,22,269,80,8,11,111,2,39,67,82,19,62,71,2,75,40,5,31,55,31,585,3,4,51,212,5,3,82,117,413,170,14,93,46,27,37,15,32,49,14,153,7,10,117,103,21,65,49,37,14,143,10,66],"type":"bar"},{"x":["techniques","stationary","dimensions","transformatio ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4556,), (4556, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.805

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Superconducting</span> <span style=''>optoelectronic</span> <span style=''>circuits</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.8461538461538461);'>neuromorphic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <br/><br/><span style=''>Neural</span> <span style=''>networks</span> <span style=''>have</span> <span style=''>proven</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effective</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>problems</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>Implementing</span> <span style=''>complex</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>in</span> <span style=''>software</span> <span style=''>is</span> <span style=''>very</span> <span style='background-color:rgba(255, 0, 0, 0.35802469135802467);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expensive</span> <span style=''>To</span> <span style=''>explore</span> <span style=''>the</span> <span style=''>limits</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.49373433583959897);'>processing</span> <span style=''>it</span> <span style=''>will</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>necessary</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implement</span> <span style=''>new</span> <span style=''>hardware</span> <span style='background-color:rgba(0, 255, 0, 0.8048780487804879);'>platforms</span> <span style=''>with</span> <span style=''>large</span> <span style=''>numbers</span> <span style=''>of</span> <span style=''>neurons</span> <span style=''>each</span> <span style=''>with</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connections</span> <span style=''>to</span> <span style=''>other</span> <span style=''>neurons</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>hybrid</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>semiconductor</span> <span style=''>superconductor</span> <span style=''>hardware</span> <span style=''>platform</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementation</span> <span style=''>of</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.8461538461538461);'>neuromorphic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <span style=''>The</span> <span style=''>platform</span> <span style=''>combines</span> <span style=''>semiconducting</span> <span style=''>few</span> <span style=''>photon</span> <span style=''>light</span> <span style=''>emitting</span> <span style=''>diodes</span> <span style=''>with</span> <span style=''>superconducting</span> <span style=''>nanowire</span> <span style=''>single</span> <span style=''>photon</span> <span style='background-color:rgba(0, 255, 0, 0.7209302325581395);'>detectors</span> <span style=''>to</span> <span style=''>behave</span> <span style=''>as</span> <span style=''>spiking</span> <span style=''>neurons</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.49373433583959897);'>processing</span> <span style=''>units</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.32743362831858414);'>connected</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Fourier</span> <span style=''>features</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style=''>brings</span> <span style=''>together</span> <span style=''>two</span> <span style=''>powerful</span> <span style=''>concepts</span> <span style=''>in</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>and</span> <span style=''>the</span> <span style=''>spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>This</span> <span style=''>gives</span> <span style=''>rise</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>that</span> <span style=''>inherits</span> <span style=''>the</span> <span style=''>benefits</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>approach</span> <span style=''>but</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representational</span> <span style=''>power</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scalability</span> <span style=''>of</span> <span style=''>spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>The</span> <span style=''>work</span> <span style=''>hinges</span> <span style=''>on</span> <span style=''>a</span> <span style=''>key</span> <span style=''>result</span> <span style=''>that</span> <span style=''>there</span> <span style=''>exist</span> <span style=''>spectral</span> <span style=''>features</span> <span style=''>related</span> <span style=''>to</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>domain</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>which</span> <span style=''>exhibit</span> <span style=''>almost</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariances</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressions</span> <span style=''>for</span> <span style=''>Matern</span> <span style=''>kernels</span> <span style=''>in</span> <span style=''>one</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>to</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensions</span> <span style=''>using</span> <span style=''>kernels</span> <span style=''>with</span> <span style=''>specific</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>Under</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>of</span> <span style=''>additive</span> <span style=''>Gaussian</span> <span style=''>noise</span> <span style=''>our</span> <span style=''>method</span> <span style=''>requires</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Parallel</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>with</span> <span style=''>Upper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Confidence</span> <span style=''>Bound</span> <span style=''>and</span> <span style=''>Pure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exploration</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenge</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximizing</span> <span style=''>an</span> <span style=''>unknown</span> <span style=''>function</span> <span style=''>f</span> <span style=''>for</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>evaluations</span> <span style=''>are</span> <span style=''>noisy</span> <span style=''>and</span> <span style=''>are</span> <span style=''>acquired</span> <span style=''>with</span> <span style=''>high</span> <span style=''>cost</span> <span style=''>An</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>uses</span> <span style=''>the</span> <span style=''>previous</span> <span style=''>measures</span> <span style=''>to</span> <span style=''>actively</span> <span style=''>select</span> <span style=''>the</span> <span style=''>next</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>f</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicted</span> <span style=''>to</span> <span style=''>be</span> <span style=''>the</span> <span style=''>most</span> <span style=''>useful</span> <span style=''>We</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style=''>case</span> <span style=''>where</span> <span style=''>the</span> <span style=''>function</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3072625698324022);'>evaluated</span> <span style=''>in</span> <span style=''>parallel</span> <span style=''>with</span> <span style=''>batches</span> <span style=''>of</span> <span style=''>fixed</span> <span style=''>size</span> <span style=''>and</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>benefit</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>the</span> <span style=''>purely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cumulative</span> <span style=''>regret</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>Upper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Confidence</span> <span style=''>Bound</span> <span style=''>and</span> <span style=''>Pure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exploration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>(GP</span> <span style=''>UCB</span> <span style=''>PE)</span> <span style=''>which</span> <span style=''>combines</span> <span style=''>the</span> <span style=''>UCB</span> <span style=''>strategy</span> <span style=''>and</span> <span style=''>Pure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exploration</span> <span style=''>in</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style=''>Reliable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <span style=''>of</span> <span style=''>Concept</span> <span style=''>Drift</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Streaming</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Unlabeled</span> <span style=''>Data</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Classifiers</span> <span style=''>deployed</span> <span style=''>in</span> <span style=''>the</span> <span style=''>real</span> <span style=''>world</span> <span style=''>operate</span> <span style=''>in</span> <span style=''>a</span> <span style=''>dynamic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environment</span> <span style=''>where</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>can</span> <span style=''>change</span> <span style=''>over</span> <span style=''>time</span> <span style=''>These</span> <span style=''>changes</span> <span style=''>referred</span> <span style=''>to</span> <span style=''>as</span> <span style=''>concept</span> <span style=''>drift</span> <span style=''>can</span> <span style=''>cause</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>to</span> <span style=''>drop</span> <span style=''>over</span> <span style=''>time</span> <span style=''>thereby</span> <span style=''>making</span> <span style=''>it</span> <span style=''>obsolete</span> <span style=''>To</span> <span style=''>be</span> <span style=''>of</span> <span style=''>any</span> <span style=''>real</span> <span style=''>use</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>need</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>drifts</span> <span style=''>and</span> <span style=''>be</span> <span style=''>able</span> <span style=''>to</span> <span style=''>adapt</span> <span style=''>to</span> <span style=''>them</span> <span style=''>over</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detecting</span> <span style=''>drifts</span> <span style=''>has</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditionally</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approached</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>task</span> <span style=''>with</span> <span style=''>labeled</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constantly</span> <span style=''>being</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validating</span> <span style=''>the</span> <span style=''>learned</span> <span style=''>model</span> <span style=''>Although</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detecting</span> <span style=''>drifts</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>impractical</span> <span style=''>as</span> <span style=''>labeling</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>costly</span> <span style=''>and</span> <span style=''>time</span> <span style='background-color: ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12293314162473042)
# 	experimental (0.13515456506110712)
# 	architecture (0.08590941768511862)
# 	processing (0.10711718188353703)
# 	information (0.23903666427030912)
# 	detection (0.11107117181883537)
# 	representation (0.14629762760603882)
# 	different (0.26779295470884257)
# 	convolutional (0.13443565780014377)
# 	recognition (0.13551401869158877)
#
# Some Statistics words are:
# 	stochastic (0.1337958374628345)
# 	variables (0.13330029732408324)
# 	estimation (0.17244796828543113)
# 	statistical (0.15609514370664024)
# 	inference (0.1823587710604559)
# 	algorithm (0.39444995044598613)
# 	theoretical (0.15807730426164518)
# 	distribution (0.18483647175421208)
# 	dimensional (0.18929633300297324)
# 	regression (0.18681863230921705)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="57c96468-6787-4acb-b677-df16af98f82b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57c96468-6787-4acb-b677-df16af98f82b")) {                    Plotly.newPlot(                        "57c96468-6787-4acb-b677-df16af98f82b",                        [{"x":["techniques","stationary","dimensions","transformation","integration","approximation","estimation","relationship","sufficiently","characteristic","arbitrary","rightarrow","increasingly","highlight","distributed","uniformly","approximated","normalized","parameter","introducing","exponential","quantifiers","algorithms","recursion","complexity","processing","potentially","probability","interesting","theoretical","inconvenient","understanding","currently","previously","inference","existential","identified","skolemization","relational","therefore","evaluating","terminology","furthermore","alternative","revisiting","summarization","summaries","effectiveness","effective","sentences","approaches","evaluation","generated","correlations","scientific","corresponding","different","extensive","consistently","variations","paraphrasing","similarities","relevance","knowledge","unsupervised","metaheuristics","discussed","structures","fundamental","exploited","optimization","combination","objective","preexisting","lexicographic","mechanism","performance","nonlinear","information","disadvantages","transforms","effectively","algorithm","representation","dimensional","advantages","evolutionary","appearance","representative","determined","recognizing","implemented","distinction","cooperative","alleviating","classification","experimental","measuring","minimizing","intuition","recognition","similarity","complicated","reference","transitions","filtering","correspond","reconstructing","quantifies","intrinsic","predictive","underlying","estimates","reconstruction","partition","frameworks","introduces","structure","according","perspective","application","detection","demonstrated","important","supporting","cognitive","computational","artificial","principles","attraction","implements","prototypical","autonomous","selective","comprises","recurrent","equilibrium","attractors","implement","separation","operating","presentation","plasticity","neuromorphic","experiments","connectivity","attractor","relaxation","parameters","following","associative","primitives","retrieval","memorized","connection","exploiting","appropriate","homogeneous","evolution","comparing","phenomenological","simulated","navigation","topologies","implementations","adaptation","heterogeneous","demonstrate","memristors","memristor","connections","properties","comprised","memristive","scenarios","evaluated","applications","specifically","multipliers","structured","meaningful","alternating","regularized","minimized","quadratic","biological","compressive","resulting","regularize","abundance","simultaneously","conventional","illustrated","correlation","consisting","substantially","hyperspectral","introduced","innovative","minimization","conducted","incremental","constraints","illustrate","generative","indicates","discriminative","improvement","distortion","classifiers","character","repeatedly","diversity","selection","iterative","developed","polynomial","capability","expansion","cascading","classifier","obtaining","computationally","competitive","description","quantization","procedure","compression","conflicts","principle","retraining","literature","bernoulli","processes","eigenvector","associated","eigenvectors","parametrized","implementation","technical","optimized","independently","separated","extremely","eigenvalue","statistics","determinantal","constraint","integrating","framework","denoisers","consensus","deterministic","integrate ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	determinantal
# 	inversions
# 	scientist
# 	subsample
# 	misspecified
# 	asymptotics
# 	simplemkl
# 	layerwise
# 	itinerary
# 	applicative
# 	assimilation
# 	distribute
# 	covariates
# 	substituting
# 	automates
# 	connectome
# 	consortium
# 	underdetermined
# 	horizontally
# 	jacobians
# Some words which never appear in Statistics papers:
# 	quantifiers
# 	existential
# 	skolemization
# 	paraphrasing
# 	metaheuristics
# 	lexicographic
# 	memorized
# 	phenomenological
# 	memristors
# 	memristor
# 	denoisers
# 	polysemous
# 	disambiguation
# 	semantical
# 	memoization
# 	propagator
# 	compilation
# 	evidences
# 	offspring
# 	epistasis

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0887076847047197e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7658333333333334
